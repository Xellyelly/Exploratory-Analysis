# %%
## import important libaries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
#df = pd.read_csv('path_to_file/movies.csv')
df = pd.read_csv(r"C:\Users\H\Downloads\movies.csv")
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
## check for missing data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# name         0.000000
# rating       1.004173
# genre        0.000000
# year         0.000000
# released     0.026082
# score        0.039124
# votes        0.039124
# director     0.000000
# writer       0.039124
# star         0.013041
# country      0.039124
# budget      28.312467
# gross        2.464789
# company      0.221701
# runtime      0.052165
# dtype: float64

# %%
for col in df.columns:
    missing = np.mean(df[col].isnull())
    print('{}-{:.2}%'.format(col,missing*100))
# Out:
# name-0.0%
# rating-1.0%
# genre-0.0%
# year-0.0%
# released-0.026%
# score-0.039%
# votes-0.039%
# director-0.0%
# writer-0.039%
# star-0.013%
# country-0.039%
# budget-2.8e+01%
# gross-2.5%
# company-0.22%
# runtime-0.052%

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
print('No of rows including null values:',df.shape[0])
# Out:
# No of rows including null values: 7668

# %%
df1 = df.dropna()
print('No of rows including null values:',df1.shape[0])
# Out:
# No of rows including null values: 5421

# %%
# to check percentage of dataset remaining
percentage_remaining = df1.shape[0]/df.shape[0]*100
print(f"Percentage of dataset remaining: {percentage_remaining:.1f}%")
# Out:
# Percentage of dataset remaining: 70.7%

# %%
# check for duplicates
df1.duplicated().sum()
# Out:
# 0

# %%
# check data types of columns
df1.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# changing data types
df1.copy()
df1['gross'] = df1['gross'].astype('int64')
df1['budget'] = df1['budget'].astype('int64')

df1.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
# create correct year column
df1 = df1.copy()  
df1['year_correct'] = df1['released'].str.split(' ').str.get(2)

# %%
df2=df1.sort_values(by='gross',ascending=False)
df2.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
plt.figure(figsize=(7,5))
plt.scatter(x=df2['budget'],y=df2['gross'])
plt.xlabel('budget for film')
plt.ylabel('gross earning')
plt.title('budget vs gross')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.regplot(x=df2['budget'],y=df2['gross'],line_kws={'color':'blue'},scatter_kws={'color':'red'},marker='o')
plt.title('budget vs gross')
plt.figure(figsize=(9,5))

plt.show()

# %% [markdown]
# ## There are different types of correlation
# 1) Pearson (default)
# 2) Spearman
# 3) Kendall Tau
# 4) piont Biserial

# %%
corr_matrix = df1.corr(numeric_only=True,method='pearson')
corr_matrix
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
sns.heatmap(corr_matrix,annot=True,)
plt.xlabel('movies features')
plt.ylabel('movies features')
plt.title('corr matrix for numeric features')
# Out:
# Text(0.5, 1.0, 'corr matrix for numeric features')

# %%
df_num = df2
for col in df_cat.columns:
    if df_num[col].dtypes=='object':
        df_num[col]=df_num[col].astype('category')
        df_num[col]=df_num[col].cat.codes

# %%
df_num.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
#
#       star  country     budget       gross  company  runtime  year_correct
# 5445  1534       47  237000000  2847246203     1382    162.0            31
# 7445  1470       47  356000000  2797501328      983    181.0            41
# 3045  1073       47  200000000  2201647264     1382    194.0            19
# 6663   356       47  245000000  2069521700      945    138.0            37
# 7244  1470       47  321000000  2048359754      983    149.0            40

# %%
sns.heatmap(df_num.corr(),annot=True,)
plt.xlabel('movies features')
plt.ylabel('movies features')
plt.title('corr matrix for numeric features')
plt.show()

# %%
df_num.corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating       -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre         0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year          0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released     -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score         0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes         0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director      0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer        0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star         -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country      -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget        0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
corr_pairs = df_num.corr().unstack()
corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.029234
#               genre           0.010996
#               year            0.025542
#               released       -0.006152
#               score           0.014450
#               votes           0.012615
#               director        0.015246
#               writer          0.012880
#               star           -0.006882
#               country        -0.025490
#               budget          0.023392
#               gross           0.005639
#               company         0.021697
#               runtime         0.010850
#               year_correct    0.026784
# rating        name           -0.029234
#               rating          1.000000
#               genre           0.147796
#               year            0.019499
#               released        0.018083
#               score           0.065983
#               votes           0.006031
#               director        0.014656
# ...

# %%
sorted_pairs=corr_pairs.sort_values()
sorted_pairs
# Out:
# genre         budget         -0.368523
# budget        genre          -0.368523
# gross         genre          -0.244101
# genre         gross          -0.244101
# rating        budget         -0.203946
# budget        rating         -0.203946
# rating        gross          -0.181906
# gross         rating         -0.181906
# votes         genre          -0.135990
# genre         votes          -0.135990
# company       rating         -0.092357
# rating        company        -0.092357
# year          genre          -0.073167
# genre         year           -0.073167
# country       year_correct   -0.071611
# year_correct  country        -0.071611
# company       genre          -0.071334
# genre         company        -0.071334
# year_correct  genre          -0.067962
# genre         year_correct   -0.067962
# year          country        -0.066748
# country       year           -0.066748
# runtime       genre          -0.059237
# genre         runtime        -0.059237
# ...

# %%
#high_corr =sorted_pairs[(sorted_pairs)>5]
high_corr = sorted_pairs[(sorted_pairs > 0.5) | (sorted_pairs < -0.5)]
print(high_corr)
# Out:
# votes         gross           0.614751
# gross         votes           0.614751
#               budget          0.740247
# budget        gross           0.740247
# year_correct  year            0.994821
# year          year_correct    0.994821
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# year_correct  year_correct    1.000000
# dtype: float64
